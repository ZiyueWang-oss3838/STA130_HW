# %% [markdown]
# A clear statement of the specific research question you’ve formulated:
#
# Topic: How do people doing exercising regularly affect their self-rated physical health?
#
# Why it is interesting to study this topic: Studying people's frequency on doing exercising in relation to their self-rated physical health can help people understand the benefit of doing regular exercising on physical health.
#
# population: Canadian people
#
# population parameter:
#     1) average exercise score (rate from 1 to 13)
#     2) average self-rate physical health (rate from 1 to 10)
#     3) the proportion of people rate their physical health as excellent or good and their average exercise score.
#     4) the proportion of people rate their physical health as bad or fair and their average exerice score
#
# Variables:
#
# Independent variables:
# average exercise score (rate from 1 to 13)
# 1134.	2022_cross	Q110_3	LIFESTYLE_time_use_priorities_exercise_actual	How do YOU prioritize each of the following activities in your daily life? Note: Please answer the question based on how you actually live, not based on how you would like to live. Your top priority should be scored as a 1 and your bottom priority should be scored as a 13. You are only able to assign one activity to each priority level. It is helpful to read all the options first before assigning priority levels to each activity. - Exercising regularly
#
# Dependent variables (outcomes):
# average self-rate physical health (rate from 1 to 10)
# 185.	2021_cross	Q60	WELLNESS_self_rated_physical_health	At the present time, would you say your PHYSICAL HEALTH is:
#
# self-information variables (helps on collecting data):
# 10.	2021_cross	RecipientLastName	SURVEY_last_name	Recipient Last Name
# 11.	2021_cross	RecipientFirstName	SURVEY_first_name	Recipient First Name

# %% [markdown]
# Describe the variables you plan to explore and how you plan on exploring them:
#
# Briefly discuss why you are choosing these variables:
#
#
# Independent variables:
# average exercise score (rate from 1 to 13)
# 1134.	2022_cross	Q110_3	LIFESTYLE_time_use_priorities_exercise_actual	How do YOU prioritize each of the following activities in your daily life? Note: Please answer the question based on how you actually live, not based on how you would like to live. Your top priority should be scored as a 1 and your bottom priority should be scored as a 13. You are only able to assign one activity to each priority level. It is helpful to read all the options first before assigning priority levels to each activity. - Exercising regularly
#
# Explaination:
# This score (rating from 1 to 13) reflect people's emphasis on sports and frequency on doing sport. A lower score reflects people have a stronger emphasis and higher frequency on doing sport. A higher score reflects people have a weaker emphasis and lower frequency on doing sport.
#
# Why I choose this variables:
# Understanding people's emphasis and frequency on doing sport in relation to their self-rated health score. Compare the self-rated physical health between people with high and low frequency on doing exercise. This highlines the importance of doing exercise to get a better health.
#
#
# Dependent variables (outcomes):
# average self-rate physical health (rate as 4 levels: Excellent, good, fair, bad)
# 185.	2021_cross	Q60	WELLNESS_self_rated_physical_health	At the present time, would you say your PHYSICAL HEALTH is:
#
# Explaination:
# The self-rated level(excellent, good, fair, bad) reflect how people rate their own physical health.
#
# Why I choose this variables:
# Self-rated physical health can predict their real physical health. By comparing the self-rated physical health and average exercise score, we can explore whether higher average exercise score can bring people a higher self-rate physical health.
#
#
# summary statistics:
# for Average health score, find Mean, Median, standard deviation, range(minimum, 25%, median(50%), 75%, maximum, outliner), Interquartile Range (IQR)
# proportion for each self-rate physical health (Excellent, good, fair, bad)
# proportion of each self-rate physical health for each average health score
#
# plots/visualizations:
#
# types of visualizations I will use:
# histogram for self-rate physical health
# justification: A histogram shows a visualizations of the proportion for self-rated physical health rating from 1 to 10. This shows which self-rate physical health has the highest proportion and the lowest proportion, and reflects people's physical health in society.
#
# box plot visualization for average health score
# justification: A box plot shows a visualizations of

# %% [markdown]
# Describe the analysis you plan to perform:
# Using bootstrapping
#
# 1. collect data and defined groups:
# collect the data of the average health score, divide the data into two group, people with high exercice frequency (rating score from 1 to 5), and people with low exercise frequency (rating score from 6 to 13).
#
# 2. create bootstrap samples:
# For the two groups, people with high exercice frequency (rating score from 1 to 5), and people with low exercise frequency(rating score from 6 to 13), do bootstrapping on their self-rated health score and randomly take data from each group to create 1000 bootstrap samples.
#
# 3. calculate sample standard deviation(s) and means differences between two groups:
# Using the formula of sample standard deviation(s) to calculate difference in mean for the two groups. Calculate Mean, Median, standard deviation, range(minimum, 25%, median(50%), 75%, maximum, outliner), Interquartile Range (IQR), and use the box plot to shows the two datas: the mean of people with high exercice frequency (rating score from 1 to 5), and the mean of people with low exercise frequency(rating score from 6 to 13). This will shows a mean differences on self-rated health score in between high vs. low exercise frequency in population.
#
# 4. Estimate Confidence Interval:
# Calculate 95% confidence interval for the difference in means for two groups. If 95% confidence interval does not have zero, it means there is significant difference on their self-rated physical health between people with high exercice frequency (rating score from 1 to 5)  and people with low exercise frequency (rating score from 6 to 13) in average exercise score.
#
#
# 5. Hypothesis testing:
# Null Hypothesis(H0): There is no difference on their self-rated health score between people with high exercice frequency (rating score from 1 to 5)  and people with low exercise frequency (rating score from 6 to 13) in average exercise score.
# Alternative Hypothesis (Ha): There is significant difference on their self-rated health score between people with high exercice frequency (rating score from 1 to 5)  and people with low exercise frequency (rating score from 6 to 13) in average exercise score.
#
# Assumption for bootstrapping:
# Independence: Each individual's average exercise score and self-rate physical health score are independent datas.
# Reliability with Uneven Samples: bootstrapping can solve the problems with uneven samples, such as the numbers of individuals in two groups are difference.

# %% [markdown]
# Make a hypothesis for the possible results your analysis may produce and describe how these results would be relevant in answering your research question:
#
# Null hypothesis (H0): People who has a high rating score on average exercise score will have higher average self-rated health (ex. Good, Excellent). However, individuals who has a lower rating score on average exercise score will have a lower average self-rated physical health (ex. Fair, Poor)
#
# Alternative hypothesis (Ha): There is no relation in between a high rating score on average exercise score and a average self-rated health.
#
# Hypothesized results:
# The Null hypothesis is found. People who has a high rating score on average exercise score will have higher average self-rated health (ex. Good, Excellent). However, individuals who has a lower rating score on average exercise score will have a lower average self-rated physical health (ex. Fair, Poor). Doing exercise can improve people's physical health.
#
# The Alternative hypothesis is found. There is no relation in between a high rating score on average exercise score and a average self-rated health. Doing exercise cannot improve people's physical health.
